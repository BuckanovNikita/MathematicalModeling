# %% [markdown]
# # Лабораторная работа № 10
#
# ## Исследование стационарной модели распределения властных полномочий.

# %% [markdown]
# 1. Идеализация объекта исследования.
# 2. План построения математической модели.
# 3. Переход к непрерывной модели.
# 4. Обезразмеривание задачи.
# 5. Стационарный случай. Получение аналитического решения. Его анализ в зависимости от параметров системы.
# 6. Выход за рамки полномочий, роль и влияние основных характеристик системы

# %% [markdown]
# Упрощающие предположения
# * Распределение граждан по доходам для среднего класса подчиняется нормальному закону.
#
# * В зоне реальных доходов будет гипотетический товар с некоторой ценой, и в Δ-окрестности от этой цены будет 100% потребления данного товара.

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact
import ipywidgets as widgets
import scipy.integrate as integrate
# Out:
# C:\Users\nikita\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %%
# %matplotlib notebook
style = {'description_width': 'initial'}

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.grid()
ind = 0

def plotter(mean_sallary, std_dev, real_price, percent):
    global ind
    if ind%5 == 0:
        ax.clear()
        ax.grid()
    x = np.linspace(real_price, 50000, 10000)
    ax.plot(x, (1 - norm.cdf(100*x/percent, mean_sallary, std_dev))*(x - real_price))
    ind+=1
    
interact(plotter,
    mean_sallary=widgets.IntSlider(min=1000, max=200000, step=1000, value=22000,style = style),
    std_dev=widgets.IntSlider(min=1000, max=10000, step=100, value=5000,style = style),
    real_price = widgets.IntSlider(min=100, max=100000, step=100, value=500,style = style),
    percent = widgets.IntSlider(min=1, max=100, step=1, value=10,style = style)
);
# Out:
# <img src="data:image/png;base64,..." width="NaN">
# interactive(children=(IntSlider(value=22000, description='mean_sallary', max=200000, min=1000, step=1000, styl…
